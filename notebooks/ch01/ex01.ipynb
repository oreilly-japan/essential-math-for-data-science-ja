# %% [markdown]
# # 1章 基礎数学と微積分のおさらい

# %% [markdown]
# 例1-1 Pythonでの実行結果

# %%
my_value = 2 * (3 + 2)**2 / 5 - 4
my_value
# Out:
# 6.0

# %% [markdown]
# 例1-2 Pythonで括弧を用いて分かりやすくした例

# %%
my_value = 2 * ((3 + 2)**2 / 5) - 4
my_value
# Out:
# 6.0

# %% [markdown]
# 例1-3 Pythonで変数を定義して乗算する例

# %%
x = int(input("数値を入力してください\n"))

product = 3 * x

product
# Out:
# 数値を入力してください
# 2
# 6

# %% [markdown]
# 例1-4 Pythonでのギリシャ文字の変数名の例

# %%
beta = 1.75
theta = 30.0

# %% [markdown]
# 例1-5 Pythonで添え字付き変数を表現した例

# %%
x1 = 3
x2 = 10
x3 = 44

# %% [markdown]
# 例1-6 Pythonで一次関数を宣言する例

# %%
def f(x):
    return 2 * x + 1


x_values = [0, 1, 2, 3]

for x in x_values:
    y = f(x)
    print(y)
# Out:
# 1
# 3
# 5
# 7

# %% [markdown]
# 例1-7 SymPyを使ってPythonで一次関数を描画する例
#
# ---

# %%
from sympy import *

x = symbols('x')
f = 2*x + 1
f
# Out:
# 2*x + 1

# %%
plot(f);

# %% [markdown]
# 例1-8 指数関数を描画する例

# %%
from sympy import *

x = symbols('x')
f = x**2 + 1
f
# Out:
# x**2 + 1

# %%
plot(f);

# %% [markdown]
# 例1-9 Pythonで2つの独立変数を使った関数を定義する例

# %%
from sympy import *
from sympy.plotting import plot3d

x, y = symbols('x y')
f = 2*x + 3*y
f
# Out:
# 2*x + 3*y

# %%
plot3d(f);

# %% [markdown]
# 例1-10 総和をPythonで実行する例

# %%
summation = sum(2*i for i in range(1,6))
summation
# Out:
# 30

# %% [markdown]
# 例1-11 Pythonで要素の総和を求める例

# %%
x = [1, 4, 6, 2]
n = len(x)

summation = sum(10*x[i] for i in range(0,n))
summation
# Out:
# 130

# %% [markdown]
# 例1-12 Pythonでlog関数を使用する例

# %%
from math import log

# 2を何乗すれば8になるか
x = log(8, 2)

x
# Out:
# 3.0

# %% [markdown]
# 例1-13 Pythonで月ごとに福利計算する例

# %%
p = 100
r = 0.20
t = 2.0
n = 12

a = p * (1 + (r/n))**(n * t)

a
# Out:
# 148.69146179463576

# %% [markdown]
# 例1-14 Pythonで連続的な複利計算を行う例

# %%
from math import exp

p = 100 # 元本、開始時の金額
r = 0.20 # 年ごとの金利
t = 2.0 # 年数

a = p * exp(r*t)

a
# Out:
# 149.18246976412703

# %% [markdown]
# 例1-15 Pythonで10の自然対数を計算する例

# %%
from math import log

# eを何乗すれば10になるか
x = log(10)

x
# Out:
# 2.302585092994046

# %% [markdown]
# 例1-16 SymPyを使って極限を求める例

# %%
from sympy import *

x = symbols('x')
f = 1 / x
f
# Out:
# 1/x

# %%
result = limit(f, x, oo)
result
# Out:
# 0

# %% [markdown]
# 例1-17 Pythonでの微分計算機

# %%
def derivative_x(f, x, step_size):
    m = (f(x + step_size) - f(x)) / ((x + step_size) - x)
    return m


def my_function(x):
    return x**2

slope_at_2 = derivative_x(my_function, 2, 0.00001)

slope_at_2
# Out:
# 4.000010000000827

# %% [markdown]
# 例1-18 SymPyで導関数を求める例

# %%
from sympy import *

# SymPyで'x'を定義する
x = symbols('x')

# Pythonの構文で関数を宣言する
f = x**2
f
# Out:
# x**2

# %%
# この関数の導関数を求める
dx_f = diff(f)
dx_f
# Out:
# 2*x

# %% [markdown]
# 例1-19 Pythonで書き直した例

# %%
def f(x):
    return x**2

def dx_f(x):
    return 2*x

slope_at_2 = dx_f(2.0)

slope_at_2
# Out:
# 4.0

# %% [markdown]
# 例1-20 SymPyの代入機能を使った例

# %%
from sympy import *

# SymPyで'x'を定義する
x = symbols('x')

# Pythonの構文で関数を宣言する
f = x**2
f
# Out:
# x**2

# %%
# この関数の導関数を求める
dx_f = diff(f)
dx_f
# Out:
# 2*x

# %%
# x = 2での傾きを求める
dx_f.subs(x,2)
# Out:
# 4

# %% [markdown]
# 例1-21 SymPyで偏微分を求める例

# %%
from sympy import *
from sympy.plotting import plot3d

# SymPyでxとyを定義する
x,y = symbols('x y')

# Pythonの構文で関数を宣言する
f = 2*x**3 + 3*y**3
f
# Out:
# 2*x**3 + 3*y**3

# %%
# xとyの偏微分を求める
dx_f = diff(f, x)
dx_f
# Out:
# 6*x**2

# %%
dy_f = diff(f, y)
dy_f
# Out:
# 9*y**2

# %%
# 関数を描画する
plot3d(f);

# %% [markdown]
# 例1-22 極限を使って傾きを求める例

# %%
from sympy import *

# xと、傾きsを定義する
x, s = symbols('x s')

# 関数を宣言する
f = x**2

# %%
f
# Out:
# x**2

# %%
# 傾きの公式に代入して、
# sだけ離れた2点間の傾きを求める
slope_f = (f.subs(x, x + s) - f) / ((x+s) - x)
slope_f
# Out:
# (-x**2 + (s + x)**2)/s

# %%
# xに2を代入する
slope_2 = slope_f.subs(x, 2)

# %%
slope_2
# Out:
# ((s + 2)**2 - 4)/s

# %%
# x = 2のときの傾きを求める
# 間隔_s_を限りなく0に近づける
result = limit(slope_2, s, 0)

# %%
result
# Out:
# 4

# %% [markdown]
# 例1-23 極限を使って導関数を求める例

# %%
from sympy import *

# xと、傾きsを定義する
x, s = symbols('x s')

# 関数を宣言する
f = x**2
f
# Out:
# x**2

# %%
# 傾きの公式に代入して、
# sだけ離れた2点間の傾きを求める
slope_f = (f.subs(x, x + s) - f) / ((x+s) - x)
slope_f
# Out:
# (-x**2 + (s + x)**2)/s

# %%
# 導関数を求める
# 間隔_s_を限りなく0に近づける
result = limit(slope_f, s, 0)
result
# Out:
# 2*x

# %% [markdown]
# 例1-24 $x$に対する$z$の導関数を求める例

# %%
from sympy import *

x = symbols('x')
z = (x**2 + 1)**3 - 2
z
# Out:
# (x**2 + 1)**3 - 2

# %%
dz_dx = diff(z, x)
dz_dx
# Out:
# 6*x*(x**2 + 1)**2

# %% [markdown]
# 例1-25 連鎖律の有無にかかわらず同じ導関数dz/dxが得られる例

# %%
from sympy import *

x, y = symbols('x y')


# 1つ目の関数の導関数
# 変数の衝突を避けるために yの前にアンダースコアを付ける
_y = x**2 + 1
dy_dx = diff(_y)
dy_dx
# Out:
# 2*x

# %%
# 2つ目の関数の導関数
z = y**3 - 2
dz_dy = diff(z)
dz_dy
# Out:
# 3*y**2

# %%
# 連鎖律を使って求めた導関数と、yを代入して直接求めた導関数
dz_dx_chain = (dy_dx * dz_dy).subs(y, _y)
dz_dx_no_chain = diff(z.subs(y, _y))

# %%
# 両者が等しいことを示し、連鎖律を証明
dz_dx_chain
# Out:
# 6*x*(x**2 + 1)**2

# %%
dz_dx_no_chain
# Out:
# 6*x*(x**2 + 1)**2

# %% [markdown]
# 例1-26 Pythonによる積分の近似

# %%
def approximate_integral(a, b, n, f):
    delta_x = (b - a) / n
    total_sum = 0

    for i in range(1, n + 1):
        midpoint = 0.5 * (2 * a + delta_x * (2 * i - 1))
        total_sum += f(midpoint)

    return total_sum * delta_x

def my_function(x):
    return x**2 + 1

area = approximate_integral(a=0, b=1, n=5, f=my_function)

# %%
area
# Out:
# 1.33

# %% [markdown]
# 例1-27 Pythonによる積分の近似（並べる長方形を1,000個に変更）

# %%
def approximate_integral(a, b, n, f):
    delta_x = (b - a) / n
    total_sum = 0

    for i in range(1, n + 1):
        midpoint = 0.5 * (2 * a + delta_x * (2 * i - 1))
        total_sum += f(midpoint)

    return total_sum * delta_x

def my_function(x):
    return x**2 + 1

# %%
area = approximate_integral(a=0, b=1, n=1000, f=my_function)

# %%
area
# Out:
# 1.333333250000001

# %% [markdown]
# 例1-28 Pythonによる積分の近似（並べる長方形を100万個に変更）

# %%
def approximate_integral(a, b, n, f):
    delta_x = (b - a) / n
    total_sum = 0

    for i in range(1, n + 1):
        midpoint = 0.5 * (2 * a + delta_x * (2 * i - 1))
        total_sum += f(midpoint)

    return total_sum * delta_x

def my_function(x):
    return x**2 + 1

# %%
area = approximate_integral(a=0, b=1, n=1_000_000, f=my_function)

# %%
area
# Out:
# 1.3333333333332733

# %% [markdown]
# 例1-29 SymPyで積分する例

# %%
from sympy import *

# SymPyで'x'を定義する
x = symbols('x')

# Pythonの構文で関数を宣言する
f = x**2 + 1

# %%
f
# Out:
# x**2 + 1

# %%
# 関数をxについて積分し、x = 0から1の範囲の面積を求める
area = integrate(f, (x, 0, 1))

# %%
area
# Out:
# 4/3

# %% [markdown]
# 例1-30 極限を使って積分する例

# %%
from sympy import *

# SymPyで変数を定義する
x, i, n = symbols('x i n')

# 関数を宣言し、範囲を定義する
f = x**2 + 1
lower, upper = 0, 1

# 幅と、インデックスiの長方形の高さを求める
delta_x = ((upper - lower) / n)

# %%
delta_x
# Out:
# 1/n

# %%
x_i = (lower + delta_x * i)

# %%
x_i
# Out:
# i/n

# %%
fx_i = f.subs(x, x_i)

# %%
fx_i
# Out:
# i**2/n**2 + 1

# %%
# n個の長方形について繰り返し、その面積を合計する
n_rectangles = Sum(delta_x * fx_i, (i, 1, n)).doit()

# %%
n_rectangles
# Out:
# 1 + (n**3/3 + n**2/2 + n/6)/n**3

# %%
# 長方形の個数nを無限大に近づけて、面積を求める
area = limit(n_rectangles, n, oo)

# %%
area
# Out:
# 4/3
